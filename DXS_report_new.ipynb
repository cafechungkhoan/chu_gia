# %% [markdown]
# <a href="https://colab.research.google.com/github/cafechungkhoan/chu_gia/blob/master/DXS_report_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# Nhập mã cần search: dxs

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   import sys

# %%
# Out:
# CPU times: user 10.3 ms, sys: 0 ns, total: 10.3 ms
# Wall time: 10.3 ms
# CPU times: user 1.19 ms, sys: 0 ns, total: 1.19 ms
# Wall time: 1.05 ms
# CPU times: user 2.11 ms, sys: 0 ns, total: 2.11 ms
# Wall time: 1.97 ms
# CPU times: user 1.16 ms, sys: 11 µs, total: 1.17 ms
# Wall time: 1.03 ms

# %%
# Out:
# Tổng số bình luận của dxs count được =  283
# <BarContainer object of 14 artists>

# %%
# Out:
# Text(0.5, 1.0, 'Lyd - Topic Cluster')

# %%
co_ban
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
ki_thuat
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
vi_mo
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                   originalContent  ... Sentiment
# 96   Gửi mấy thanh niên có học! \nKhông biết gì thì có thể học đừng ở đó mà nói người khác. TT thì gãy trend người ta chỉ đánh PHÁI SINH trong thời điểm khó mà tăng xác suất gần bằng 0. Ở đó mà chửi. Đua nhau bắt đáy rồi than trời. Có học thì còn không mau mở tài khoản phái sinh mà SHORT để kiếm tiền mua dịch Covid-19.\nKính gửi mấy thanh niên có học :))                                                                                               ...  None
# ...

# %%
tin_don
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
data1
# Out:
#           date  Sentiment_negative  Sentiment_positive
# 0   07/15/2021  48                  12
# 1   07/16/2021  16                  6
# 2   07/17/2021  2                   1
# 3   07/19/2021  3                   3
# 4   07/20/2021  5                   0
# 5   07/21/2021  4                   1
# 6   07/22/2021  0                   1
# 7   07/23/2021  1                   1
# 8   07/24/2021  1                   0
# 9   07/26/2021  1                   0
# 10  07/27/2021  3                   1
# 11  07/28/2021  6                   2
# 12  07/29/2021  1                   1
# 13  07/30/2021  1                   0
# 14  08/01/2021  1                   0
# 15  08/02/2021  3                   0
# 16  08/03/2021  5                   0
# 17  08/04/2021  1                   0
# 18  08/05/2021  1                   1
# 19  08/06/2021  1                   0
# 20  08/09/2021  1                   0
# 21  08/10/2021  1                   0

# %%
co_ban.groupby('date').count()
# Out:
#             originalContent  user.name  Sentiment
# date
# 07/15/2021  10               10         3
# 07/16/2021  6                6          2
# 07/17/2021  1                1          0
# 07/19/2021  1                1          1
# 07/20/2021  2                2          2
# 07/21/2021  1                1          1
# 07/22/2021  1                1          0
# 07/23/2021  1                1          0
# 07/27/2021  1                1          1
# 07/29/2021  3                3          0
# 08/02/2021  1                1          1
# 08/06/2021  1                1          0
# 08/09/2021  1                1          0

# %%
vi_mo.groupby('date').count()
# Out:
#             originalContent  user.name  Sentiment
# date
# 07/15/2021  3                3          1
# 07/16/2021  2                2          2
# 07/17/2021  1                1          1
# 07/20/2021  1                1          0

# %%
ki_thuat.groupby('date').count()
# Out:
#             originalContent  user.name  Sentiment
# date
# 07/15/2021  1                1          0
# 07/19/2021  1                1          0
# 07/20/2021  1                1          0
# 07/21/2021  1                1          1
# 07/28/2021  2                2          1
# 07/30/2021  1                1          0
# 08/02/2021  1                1          0
# 08/08/2021  1                1          0

# %%
tin_don.groupby('date').count()
# Out:
#             originalContent  user.name  Sentiment
# date
# 07/15/2021  21               21         11
# 07/16/2021  7                7          2
# 07/17/2021  2                2          1
# 07/20/2021  3                3          1
# 07/21/2021  2                2          1
# 07/22/2021  1                1          0
# 07/23/2021  2                2          1
# 07/29/2021  1                1          1
# 08/02/2021  1                1          1
# 08/09/2021  1                1          0
