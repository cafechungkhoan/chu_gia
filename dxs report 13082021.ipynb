# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 286 entries, 0 to 285
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   originalContent  286 non-null    object
# dtypes: object(1)
# memory usage: 4.5+ KB
# None

# %% [markdown]
# ### Preprocessing text data

# %%
# Out:
# Processing step 1: Lower case
# Done ---- >>> Next step:
# Processing step 2: Removed Https tag
# Done ---- >>> Next step:
# Processing step 3: Tokenize lớp thứ 1
# Processing step 4: Tokenize lớp thứ 2
# Done.

# %%
# Out:
# Apllied model BERT....
# Done Vectorizer
# Applied SVM....
# Done

# %% [markdown]
# # Topic cluster

# %%
# Out:
# Text(0.5, 1.0, 'Topic Tin đồn')

# %%
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# Out:
#      label  \
# 0    1
# 160  1
#
# ...

# %%
# Out:
#      label  \
# 12   1
# 21   1
# 91   0
# 93   1
# 104  1
# 114  1
# 130  1
# 144  1
# 149  1
# 160  1
# 178  1
# 188  1
# 206  1
# 250  1
# 275  0
#
# ...

# %%
# Out:
#      label  \
# 99   1
# 239  1
#
#                                                                                                                                                                                                                                                                                                                                                      originalContent
# 99   Gửi mấy thanh niên có học! \nKhông biết gì thì có thể học đừng ở đó mà nói người khác. TT thì gãy trend người ta chỉ đánh PHÁI SINH trong thời điểm khó mà tăng xác suất gần bằng 0. Ở đó mà chửi. Đua nhau bắt đáy rồi than trời. Có học thì còn không mau mở tài khoản phái sinh mà SHORT để kiếm tiền mua dịch Covid-19.\nKính gửi mấy thanh niên có học :))
# ...
