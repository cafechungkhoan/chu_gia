# %% [markdown]
# <a href="https://colab.research.google.com/github/cafechungkhoan/chu_gia/blob/master/f319.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
uname = ----------------------------------
passw = ----------------------------------
params = {"username": uname,"password": passw}
response = requests.post("--------------------", data = params)
token = response.json()['token']
# call api
header = {"Authorization": "Bearer %s" %(token)}
api = f"----------------------------------------{a}&from=1609470526000&to=1640927696000&limit=500&offset=0&sort=created_date:desc"
api_response = requests.get(api, headers = header)

import pandas as pd
json_string = api_response.text
a_json = json.loads(json_string)
data3 = pd.DataFrame.from_dict(a_json['items'])
data3['created_date'] = data3['created_date']/1000
data3['created_date'] = pd.to_datetime(data3['created_date'], unit='s')
data3['originalContent'] = data3['content']
data3['date'] = data3['created_date']
col_drop = ['num_page',	'last_updated_date_comment'	,'user_name',	'feed_id','latest_comment_id','created_date','content']
data3 = data3.drop(col_drop,axis = 1)
data3['date'] = data3['date'].dt.strftime('%m/%d/%Y')
df = data3

# %%
#@title Top 20 Topic có chứa mã cần tìm trong comment trên F319
data3 = data3.groupby('title').count().sort_values(by='originalContent', ascending=False)
data3 = data3.reset_index()
# data3 = data3.iloc[:100]

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
x = data3['title']
y = data3['originalContent']

import seaborn as sns
sns.set_color_codes("muted")
plt.figure(figsize = (10,10))
plt.xticks(rotation=45)
sns.barplot(x=y,y =x, label ="Số lượng comment", color = '#ECDBBA').set_title('Top 20 Topic bình luận nhiều nhất F319 về mã cp')
# Out:
# Text(0.5, 1.0, 'Top 20 Topic bình luận nhiều nhất F319 về mã cp')

# %%
#@title Chi tiết Comment Fireant
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
#@title Chi tiết Topic, Comment & Timing F319
df
# Out:
#                                                                                                     title  ...        date
# 0    13/10/21: Chứng khoán hôm nay vì tương lai F0                                                         ...  10/12/2021
# 1    Nhận định thị trường ngày 12/10/2021                                                                  ...  10/11/2021
# 2    12/10/21: Chứng khoán hôm nay vì tương lai F0                                                         ...  10/11/2021
# 3    Bank sẽ đưa VNI lên 1530-1580 vào cuối năm 2021.                                                      ...  10/10/2021
# 4    VNI vượt 1.400 hay thụt lùi về 1.250                                                                  ...  10/09/2021
# 5    Cá mập DC full cổ, mắc cạn.                                                                           ...  10/08/2021
# 6    08/10/21: Bảng tin mỗi ngày vì tương lai F0 , chân thành và đỉnh cao                                  ...  10/07/2021
# ...
